# %%
from nltk.corpus import reuters
from nltk import bigrams, trigrams 
from nltk.lm.preprocessing import pad_both_ends
from nltk.lm.preprocessing import flatten


from nltk.tokenize import sent_tokenize, word_tokenize
from collections import defaultdict

# %%
from nltk.corpus import reuters

# %%
with open('corpus') as f:
    corpus = f.read()

# %%
corpus_list = []
for line in corpus.split('\n'):
    corpus_list.append(line)

# %%
label_length = len('__label__2')
y_list = []
X_list = []
for document in corpus_list:
    y_list.append(document[:label_length])
    X_list.append(document[label_length+1:])

# %%
sentence = 'i ate an apple'
sentence_word = word_tokenize(sentence)
dic = {}
new_list = [(w1, w2) for w1, w2 in list(bigrams(sentence_word, pad_right = True, pad_left = True))]
collections.Counter(new_list)
# Out:
# Counter({(None, 'i'): 1,
#          ('i', 'ate'): 1,
#          ('ate', 'an'): 1,
#          ('an', 'apple'): 1,
#          ('apple', None): 1})

# %%
bigram_dict = defaultdict(lambda: defaultdict(int))


for paragraph in X_list:
    for sentence in sent_tokenize(paragraph):
        sentence_word = word_tokenize(sentence)
        for w1, w2 in bigrams(sentence_word, pad_right = True, pad_left = True):
            bigram_dict[w1][w2] += 1

# %%
bigram_dict['even']
# Out:
# defaultdict(int,
#             {'for': 20,
#              'to': 4,
#              'if': 61,
#              'some': 5,
#              'sells': 1,
#              'a': 39,
#              'read': 14,
#              'casually': 1,
#              'mocked': 1,
#              'his': 4,
#              'better': 23,
#              'looked': 2,
#              'the': 60,
#              'when': 16,
#              'toys': 1,
#              'so': 3,
#              'have': 23,
#              'amazing': 1,
#              'come': 7,
#              'really': 3,
#              'use': 6,
#              'replied': 1,
#              'in': 21,
#              'tell': 6,
#              'said': 1,
#              'seemed': 1,
#              'more': 67,
#              'though': 70,
#              'go': 5,
#              'compared': 3,
#              'greater': 2,
#              'until': 1,
#              'fit': 4,
#              'that': 12,
#              'three': 1,
#              'pseudo-psychology': 1,
#              'close': 12,
#              'weaker': 3,
#              'at': 6,
#              'made': 4,
#              'smile': 1,
#              'contain': 2,
#              'sympathetic': 1,
#              'think': 7,
#              'good': 3,
#              'one': 7,
#              'particularly': 1,
#              'you': 1,
#              'finish': 11,
#              'many': 1,
#              'want': 4,
#              'be': 10,
#              'worse': 21,
#              'return': 4,
#              'sleep': 2,
#              'seems': 2,
#              'help': 1,
#              'wear': 1,
#              'notice': 2,
#              'know': 11,
#              'worthy': 1,
#              'without': 3,
#              'an': 7,
#              'any': 1,
#              'seem': 1,
#              'takes': 1,
#              'majoring': 1,
#              'half': 3,
#              'classified': 1,
#              'existed': 1,
#              'care': 2,
#              '.': 1,
#              'he': 5,
#              'food': 1,
#              'work': 5,
#              'bad': 2,
#              'left': 1,
#              'look': 1,
#              'now': 2,
#              'with': 26,
#              'easier': 2,
#              'then': 6,
#              'worth': 9,
#              'licensed': 1,
#              'open.The': 1,
#              'hold': 3,
#              'today': 5,
#              'take': 4,
#              'get': 12,
#              'charge.Flakey': 1,
#              'MacAlly': 1,
#              'stay': 1,
#              'two': 2,
#              '2': 2,
#              'tried': 3,
#              'musical': 1,
#              'mention': 3,
#              'after': 14,
#              'specify': 2,
#              'wan': 1,
#              'able': 2,
#              'hot': 1,
#              'higher': 2,
#              'ordered': 1,
#              'readers': 1,
#              'talk': 2,
#              'Israel': 1,
#              'sure': 2,
#              'fun': 2,
#              'passable': 1,
#              'give': 5,
#              'titanium': 1,
#              'political': 1,
#              'pacific': 1,
#              'inevitably': 1,
#              'unknowingly': 1,
#              'bother': 14,
#              'touched': 2,
#              'before': 6,
#              'turn': 4,
#              'considering': 1,
#              'prefer': 1,
#              'turning': 1,
#              'showed': 1,
#              'Highsmith': 1,
#              'occur': 1,
#              'been': 5,
#              'remember': 6,
#              'pump': 1,
#              'adding': 1,
#              'doodles': 1,
#              'under': 1,
#              'I': 3,
#              'slept': 1,
#              'comes': 3,
#              'those': 3,
#              'grew': 1,
#              'spanish': 1,
#              'interested': 2,
#              'race': 1,
#              'composed': 1,
#              'starting': 1,
#              'MTV': 1,
#              'bigger': 1,
#              'listen': 1,
#              'fits': 1,
#              'something': 1,
#              'make': 6,
#              'my': 10,
#              'copies': 1,
#              'new': 1,
#              'offer': 2,
#              'represent': 1,
#              'sound': 1,
#              'they': 4,
#              'pick': 1,
#              'detect': 1,
#              'begin': 5,
#              'touch': 1,
#              'out': 2,
#              'responded': 1,
#              'very': 2,
#              'upped': 1,
#              'Tess': 1,
#              'shed': 1,
#              'try': 4,
#              'better.The': 1,
#              'had': 6,
#              'included': 1,
#              'of': 1,
#              'amateur': 1,
#              'interesting': 2,
#              'notes': 1,
#              'rental': 1,
#              'manipulated': 1,
#              'fought': 1,
#              'liked': 2,
#              'teenagers.Poor': 1,
#              'it': 4,
#              'gave': 1,
#              'gets': 2,
#              'remotely': 5,
#              'miss': 1,
#              'smarter': 1,
#              'waste': 1,
#              'breaks': 2,
#              'singed': 1,
#              'Dulf': 1,
#              'Robert': 1,
#              'just': 2,
#              'by': 2,
#              '...': 1,
#              'promise': 1,
#              'abble': 1,
#              'need': 5,
#              'works': 2,
#              'downright': 1,
#              'feel': 1,
#              'scarier': 2,
#              'humorous': 1,
#              'both': 1,
#              'used': 5,
#              'Sony': 1,
#              'patriotic.So': 1,
#              'play': 4,
#              'buy': 2,
#              'vision': 1,
#              'went': 3,
#              'contacted': 1,
#              'B': 1,
#              'gone': 1,
#              'do': 2,
#              'as': 5,
#              'picks': 1,
#              'adore': 1,
#              'learned': 1,
#              'purchased': 1,
#              'on': 4,
#              'stole': 1,
#              'seen': 2,
#              'mid-sized': 1,
#              'realized': 1,
#              'adults.Its': 1,
#              'faithful': 1,
#              'sticking': 1,
#              'opened': 1,
#              'overnight': 2,
#              'inflate': 1,
#              'let': 1,
#              'tested': 1,
#              'keep': 1,
#              'inspired': 1,
#              'comparable': 1,
#              'sent': 2,
#              'print': 1,
#              'lock': 1,
#              'got': 3,
#              'while': 3,
#              'known': 3,
#              'invented': 1,
#              'online': 1,
#              'somewhat': 2,
#              'opening': 1,
#              'put': 3,
#              'separately': 1,
#              'like': 3,
#              'going': 1,
#              '10': 1,
#              'this': 1,
#              'harder': 2,
#              'release': 2,
#              'necessary': 1,
#              'coproduced': 1,
#              'back': 1,
#              'recognizes': 1,
#              'burns': 1,
#              'recognize': 1,
#              'has': 3,
#              'talking': 2,
#              'available': 1,
#              'less': 4,
#              'present': 1,
#              'aware': 1,
#              'laughed': 1,
#              'covers': 1,
#              'looking': 1,
#              'larger': 3,
#              'split': 1,
#              'teenagers': 1,
#              'how': 2,
#              'sat': 1,
#              'performed': 1,
#              'dusty': 1,
#              'kill': 1,
#              'bothered': 1,
#              'infuriating': 1,
#              'endanger': 1,
#              'Manos': 1,
#              'later': 1,
#              'enjoy': 2,
#              'mildly': 1,
#              'gotten': 2,
#              'altered': 1,
#              'checked': 1,
#              'shown': 1,
#              'sold': 1,
#              'me': 1,
#              'leaving': 1,
#              'lugged': 1,
#              'joking': 1,
#              'fight': 1,
#              'explained': 1,
#              'list': 1,
#              'listen/watch': 1,
#              'titles': 1,
#              'answer': 1,
#              'Velvet': 1,
#              'require': 1,
#              'heard': 3,
#              'watch': 3,
#              'helped': 1,
#              'wrote': 1,
#              'write': 1,
#              'done': 2,
#              'says': 1,
#              'fully': 1,
#              'superimposing': 1,
#              'consider': 1,
#              'refers': 1,
#              'betterthan': 1,
#              'describe': 1,
#              'reformatting': 1,
#              'replacing': 1,
#              'pervasive': 1,
#              'politics': 1,
#              ',': 1,
#              'thought': 2,
#              'watching': 1,
#              'probable': 1,
#              'funny.its': 1,
#              'rent': 2,
#              'scary': 2,
#              'learn': 1,
#              'hott.My': 1,
#              'written': 1,
#              'shakes': 1,
#              'realizing': 1,
#              'enjoyable': 2,
#              'claim': 1,
#              'not': 1,
#              'myself': 1,
#              'faster': 1,
#              'smugger': 1,
#              'believe': 1,
#              'knowing': 1,
#              'spawned': 1,
#              'Cold': 1,
#              'perverse': 1,
#              'Beatle-related': 1,
#              'throw': 1,
#              'warm': 1,
#              'room': 2,
#              'doing': 1,
#              'sometimes': 1,
#              'further': 1,
#              'young': 1,
#              'your': 1,
#              'slightly': 1,
#              'George': 1,
#              'watched': 2,
#              'exciting': 1,
#              'bring': 1,
#              'discount': 1,
#              'light': 1,
#              'playing': 1,
#              'Nobel': 1,
#              'published': 1,
#              'our': 1,
#              'their': 1,
#              'deal': 1,
#              'deserve': 2,
#              'die': 1,
#              'forgot': 1,
#              'Blake': 1,
#              'surpass': 1,
#              'see': 5,
#              'Entrapment': 1,
#              'Catherine': 1,
#              'all': 1,
#              'fuller': 1,
#              'did': 1,
#              'came': 1,
#              'likeable': 1,
#              'eferences': 1,
#              '10th': 1,
#              'finished': 2,
#              'pretend': 1,
#              'dare': 1,
#              'from': 1,
#              'quite': 1,
#              'folding': 1,
#              'say': 1,
#              'strangers': 1,
#              'multi-lingual': 1,
#              'funny': 1,
#              'tho': 1,
#              'bought': 1,
#              'repays': 1,
#              'sharper': 1,
#              '``': 1,
#              'pay': 1,
#              'break': 1,
#              'order': 1,
#              'pretty.Kylie': 1,
#              'weigh': 1,
#              'Will': 1,
#              'survive': 1,
#              'easy': 1,
#              'snapped': 1,
#              'tied': 1,
#              'audio': 1,
#              'once': 1,
#              'Brendan': 1,
#              'perfecting': 1,
#              'being': 1,
#              'there': 1,
#              'followed': 1,
#              'peel': 1,
#              'Karl': 1,
#              'taken': 1,
#              'receives': 1,
#              'picayune': 1,
#              'preparing': 1,
#              'took': 1,
#              'living': 1,
#              'compensate': 1,
#              'receive': 1,
#              'fun.Okay': 1,
#              'than': 1,
#              'lustful': 1,
#              '$': 1,
#              'supposed': 1,
#              '14': 1,
#              'smells': 1})

# %%
sum(bigram_dict['even'].values())
# Out:
# 1233

# %%
bigram_dict['even']['if']
# Out:
# 61

# %%
for w1 in bigram_dict:
    total_w1_cnt = sum(bigram_dict[w1].values())
    for w2 in bigram_dict[w1]:
        bigram_dict[w1][w2] /= total_w1_cnt

# %%
bigram_dict['even']['if']
# Out:
# 0.0494728304947283

# %%
import random

# starting words
text = ["even"]
sentence_finished = False

n_iteration = 0 

while not sentence_finished:
    
    r = 0.001
#     print(r)
#     r = random.random()

    accumulator = 0

    for word in bigram_dict[text[-1]].keys():
        n_iteration += 1

        accumulator += bigram_dict[text[-1]][word]

        if accumulator >= r:
            text.append(word)
            break
            
        if n_iteration > 30:
            break
        
           
    if text[-1] == None:
        sentence_finished = True
        break
        
    if len(text) > 10:
        sentence_finished = True
        break

print (' '.join([t for t in text if t]))
# Out:
# even for the game music !

# %%
from collections import defaultdict

temp_dict2 = defaultdict(lambda: defaultdict(int))

print(temp_dict2['apple'])

print(temp_dict2['apple']['bana'])


# [(w1, w2) -> w3 -> int]
# {
#     ('a', 'a'): {
#         'a': 0,
#         'b': 0,
#         'c': 1,
#         ...
#     },
#     ('a', 'b'): {
#         'a': 0,
#         ...
#     }
# }

# [(w1, w2, w3) -> int]
# {
#     ('a', 'a', 'a'): 0,
#     ('a', 'a', 'b'): 0,
# }
# Out:
# defaultdict(<class 'int'>, {})
# 0
